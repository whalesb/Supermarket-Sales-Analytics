# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Wale/Downloads/supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.notnull()
# Out:
#      Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0          True    True  True           True    True          True
# 1          True    True  True           True    True          True
# 2          True    True  True           True    True          True
# 3          True    True  True           True    True          True
# 4          True    True  True           True    True          True
# ..          ...     ...   ...            ...     ...           ...
# 995        True    True  True           True    True          True
# 996        True    True  True           True    True          True
# 997        True    True  True           True    True          True
# 998        True    True  True           True    True          True
# 999        True    True  True           True    True          True
#
#      Unit price  Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# 0          True      True    True   True  True  True     True  True
# ...

# %%
db=df.groupby(by="Branch").sum()
db
# Out:
# C:\Users\Wale\AppData\Local\Temp\ipykernel_13572\860370743.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   db=df.groupby(by="Branch").sum()
#         Unit price  Quantity     Tax 5%        Total       cogs  \
# Branch
# A         18625.49      1859  5057.1605  106200.3705  101143.21
# B         18478.88      1820  5057.0320  106197.6720  101140.64
# C         18567.76      1831  5265.1765  110568.7065  105303.53
#
#         gross margin percentage  gross income  Rating
# Branch
# A                   1619.047619     5057.1605  2389.2
# B                   1580.952381     5057.0320  2263.6
# C                   1561.904762     5265.1765  2319.9

# %%
branch=db.index
gross=db["gross income"]

# %%
plt.pie(gross, labels=branch, colors=['blue','red','yellow'],autopct='%1.1f%%',shadow=True,startangle=90)
plt.title('Branch Analysis')
plt.show()

# %%
plt.figure(figsize=(4,6))
plt.xticks(rotation=0)

plt.bar(branch,gross,color=['blue','red','yellow'])
plt.xlabel('Branch',fontweight='bold')
plt.ylabel('Gross income ($)',fontweight='bold')
plt.title('',color='Navy',fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sorted_data = sorted(zip(branch, gross), key=lambda x: x[1], reverse=True)
sorted_branch, sorted_gross = zip(*sorted_data)

# Plot adjustments
plt.figure(figsize=(6, 8))  # Larger figure for better visualization
bars = plt.bar(sorted_branch, sorted_gross, color=['blue', 'green', 'red'])  # Custom colors

# Add data labels
for bar, income in zip(bars, sorted_gross):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 100,  # Adjust text position
             f"${income:,}", ha='center', fontsize=10, fontweight='bold')

# Axis labels and title
plt.xlabel('Branch', fontweight='bold', fontsize=12)
plt.ylabel('Gross Income ($)', fontweight='bold', fontsize=12)
plt.title('Branch Gross Income Comparison', color='Navy', fontweight='bold', fontsize=14)

# Adjust y-axis range to emphasize differences
plt.ylim(min(gross) - 500, max(gross) + 500)

plt.xticks(fontsize=10)  # Increase x-tick font size
plt.yticks(fontsize=10)  # Increase y-tick font size

plt.show()

# %%
df.groupby(by="Customer type").count()
# Out:
#                Invoice ID  Branch  City  Gender  Product line  Unit price  \
# Customer type
# Member                501     501   501     501           501         501
# Normal                499     499   499     499           499         499
#
#                Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# Customer type
# Member              501     501    501   501   501      501   501
# Normal              499     499    499   499   499      499   499
#
#                gross margin percentage  gross income  Rating
# Customer type
# Member                             501           501     501
# Normal                             499           499     499

# %%
Customer_type=df[df["Customer type"]=='Normal']
Customer_type
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
Customer_type.sort_values(by = "gross income", ascending=False )
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 792  744-16-7898      B   Mandalay        Normal  Female   Home and lifestyle
# 166  234-65-2137      C  Naypyitaw        Normal    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 424  489-64-4354      C  Naypyitaw        Normal    Male  Fashion accessories
# 962  593-08-5916      A     Yangon        Normal  Female  Fashion accessories
# 282  490-29-1201      A     Yangon        Normal  Female    Sports and travel
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
#
# ...

# %%
normal_custmer_products=Customer_type.groupby(by="Product line").sum()
normal_custmer_products.sort_values(by="gross income", ascending=False)
# Out:
# C:\Users\Wale\AppData\Local\Temp\ipykernel_13572\802412913.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   normal_custmer_products=Customer_type.groupby(by="Product line").sum()
#                         Unit price  Quantity     Tax 5%       Total      cogs  \
# Product line
# Electronic accessories     4792.07       542  1420.9065  29839.0365  28418.13
# Fashion accessories        5290.58       463  1332.4730  27981.9330  26649.46
# Sports and travel          4623.25       427  1280.4060  26888.5260  25608.12
# Home and lifestyle         4275.73       421  1232.5660  25883.8860  24651.32
# Food and beverages         4285.96       446  1180.3440  24787.2240  23606.88
# Health and beauty          4244.84       426  1112.5095  23362.6995  22250.19
#
# ...

# %%
product=normal_custmer_products.index
gross_product=normal_custmer_products['gross income']

# %%
plt.pie(gross_product, labels=product, colors=['blue','red','yellow','grey','green','purple'],autopct='%1.1f%%',shadow=True,startangle=90)
plt.title('Product Line')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=55)

plt.bar(product,gross_product,color=['blue','red','yellow','grey','green','purple'])
plt.xlabel('Products',fontweight='bold')
plt.ylabel('Profit ($)',fontweight='bold')
plt.title('Profit Analysis by Product for Non-Member Customers',color='Navy',fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Sort products by profit
sorted_data = sorted(zip(product, gross_product), key=lambda x: x[1], reverse=True)
sorted_product, sorted_gross_product = zip(*sorted_data)

# Plot adjustments
plt.figure(figsize=(10, 6))  # Larger figure size for clarity
bars = plt.bar(sorted_product, sorted_gross_product, 
               color=['blue', 'green', 'yellow', 'grey', 'orange', 'red'])  # Custom colors

# Add data labels with two decimal places
for bar, profit in zip(bars, sorted_gross_product):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 300,  # Adjust label position
             f"${profit:,.2f}", ha='center', fontsize=10, fontweight='bold')  # Format to 2 decimal places

# Axis labels and title
plt.xlabel('Product Lines', fontweight='bold', fontsize=12)
plt.ylabel('Profit ($)', fontweight='bold', fontsize=12)
plt.title('Profit Analysis by Product for Non-Member Customers', color='Navy', fontweight='bold', fontsize=14)

# Adjust x-axis labels for better readability
plt.xticks(fontsize=10, rotation=45, ha='right')  # Rotate and align labels

# Adjust y-axis range to emphasize differences
plt.ylim(0, max(sorted_gross_product) + 1500)

plt.show()

# %%
gender_grouping=df.groupby(by='Gender').sum()
gender_grouping
# Out:
# C:\Users\Wale\AppData\Local\Temp\ipykernel_13572\200432901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gender_grouping=df.groupby(by='Gender').sum()
#         Unit price  Quantity    Tax 5%       Total       cogs  \
# Gender
# Female    27687.24      2869  7994.425  167882.925  159888.50
# Male      27984.89      2641  7384.944  155083.824  147698.88
#
#         gross margin percentage  gross income  Rating
# Gender
# Female              2385.714286      7994.425  3489.2
# Male                2376.190476      7384.944  3483.5

# %%
gender=gender_grouping.index
Gross_inc=gender_grouping['gross income']

# %%
plt.pie(Gross_inc, labels=gender, colors=['grey','green'],autopct='%1.1f%%',shadow=True,startangle=90)
plt.title('Gender Based Analysis')
plt.show()

# %%
plt.figure(figsize=(3,5))
plt.xticks(rotation=55)

plt.bar(gender,Gross_inc,color=['grey','green',])
plt.xlabel(' ',fontweight='bold')
plt.ylabel('Profit Made ($)',fontweight='bold')
plt.title('Profit Analysis based on customers gender ',color='Navy',fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
female=df[df['Gender']=='Female']
female
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
female_grouping=female.groupby(by='Product line').sum()
female_grouping.sort_values(by='gross income', ascending=False)
# Out:
# C:\Users\Wale\AppData\Local\Temp\ipykernel_13572\2555960996.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   female_grouping=female.groupby(by='Product line').sum()
#                         Unit price  Quantity     Tax 5%       Total      cogs  \
# Product line
# Food and beverages         5408.13       514  1579.5675  33170.9175  31591.35
# Fashion accessories        5330.59       530  1449.4000  30437.4000  28988.00
# Home and lifestyle         4522.16       498  1430.3275  30036.8775  28606.55
# Sports and travel          4784.32       496  1360.7010  28574.7210  27214.02
# Electronic accessories     4372.33       488  1290.5725  27102.0225  25811.45
# Health and beauty          3269.71       343   883.8565  18560.9865  17677.13
#
# ...

# %%
female_chart=female_grouping.index
female_chart_gross=female_grouping['gross income']

# %%
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    female_chart_gross, 
    labels=female_chart, 
    autopct='%1.1f%%', 
    startangle=140, 
    shadow=True  # Add shadow
)

# Add a title
plt.title('Female Trends:Product Lines')

# Add a legend
plt.legend(wedges, female_chart, title="female_chart", loc="center left", bbox_to_anchor=(1, 0.5))

# Format text
plt.setp(autotexts, size=10, weight="bold")
plt.setp(texts, size=10)

# Show the plot
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=55)

plt.bar(female_chart,female_chart_gross,color=['blue','orange','green','red','purple','brown'])
plt.xlabel('',fontweight='bold')
plt.ylabel('gross income ($)',fontweight='bold')
plt.title('Female Trends: Income based on Product Lines',color='Black',fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Sort data (optional, if needed for better presentation)
sorted_data = sorted(zip(female_chart, female_chart_gross), key=lambda x: x[1], reverse=True)
sorted_female_chart, sorted_female_chart_gross = zip(*sorted_data)

# Plot adjustments
plt.figure(figsize=(12, 6))  # Adjust figure size
bars = plt.bar(sorted_female_chart, sorted_female_chart_gross, 
               color=['blue', 'orange', 'green', 'red', 'purple', 'brown'])  # Custom colors

# Add data labels with two decimal places
for bar, gross in zip(bars, sorted_female_chart_gross):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 100,  # Adjust label position
             f"${gross:,.2f}", ha='center', fontsize=10, fontweight='bold')  # Format to 2 decimal places

# Axis labels and title
plt.xlabel('Product Lines', fontweight='bold', fontsize=12)
plt.ylabel('Gross Income ($)', fontweight='bold', fontsize=12)
plt.title('Female Trends: Income Based on Product Lines', color='Black', fontweight='bold', fontsize=14)

# Adjust x-axis labels for readability
plt.xticks(fontsize=10, rotation=45, ha='right')  # Rotate and align labels

# Adjust y-axis range for better spacing
plt.ylim(0, max(sorted_female_chart_gross) + 500)

plt.show()
